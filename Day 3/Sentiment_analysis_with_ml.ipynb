# %% [markdown]
# # Sentiment Analysis

# %%
# importing libraries 
import pandas as pd 
import nltk 
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from string import punctuation
import contractions
from unidecode import unidecode
import warnings 
warnings.filterwarnings("ignore")
from nltk.stem import WordNetLemmatizer
from sklearn.model_selection import train_test_split
from  sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer
from sklearn.metrics import accuracy_score
from sklearn.naive_bayes import MultinomialNB

# %% [raw]
# # 1. remove blank spaces,newlines
# # 2. contraction mapping
# # 3. Handling accented characters
# # 4. Cleaning : tokenization,lowercase,remove punctuation and stopwords,remove numerical format,remove single random characterss
# # 5. Lemmatization

# %%
# loading the data 
data = pd.read_csv(r"C:\Users\pjosh\Documents\NLP\22_JAN_2022\Train.csv")
data.head(2)
# Out:
#                                                 text  label
# 0  I grew up (b. 1965) watching and loving the Th...      0
# 1  When I put this movie in my DVD player, and sa...      0

# %%
# creating functions for preprocessing
def remove_newlines(data):
    formatted_text = data.replace("\\n",' ').replace("\t"," ")
    return formatted_text

def contraction_map(data):
    fixed_text = contractions.fix(data)
    return fixed_text

def handle_accented(data):
    fixed_text = unidecode(data)
    return fixed_text

stopword_list = stopwords.words("english")
stopword_list.remove("no")
stopword_list.remove("not")
stopword_list.remove("nor")
def cleaning_text(data):
    tokens = word_tokenize(data)
    clean_tokens = [ i.lower() for i in tokens if (i.lower() not in stopword_list) and (i not in punctuation) ]
    clean_tokens = [ i for i in  clean_tokens if (len(i)>1) and i.isalpha()]
    return clean_tokens

def lemmatization(data):
    lemmatizer = WordNetLemmatizer()
    final_tokens = []
    for i in data:
        lemmatized_word = lemmatizer.lemmatize(i)
        final_tokens.append(lemmatized_word)
    return " ".join(final_tokens)

# %%
# data leakage 
x_train,x_test,y_train,y_test = train_test_split(data.text,data.label,test_size=0.25,stratify=data.label,random_state=42)

# %%
clean_train = x_train.apply(remove_newlines)
clean_test = x_test.apply(remove_newlines)

clean_train = clean_train.apply(contraction_map)
clean_test = clean_test.apply(contraction_map)

clean_train = clean_train.apply(handle_accented)
clean_test = clean_test.apply(handle_accented)

clean_train = clean_train.apply(cleaning_text)
clean_test = clean_test.apply(cleaning_text)

clean_train = clean_train.apply(lemmatization)
clean_test = clean_test.apply(lemmatization)

# %% [markdown]
# # Count Vectorizer

# %%
count = CountVectorizer(max_features=1000,max_df=0.95,min_df=1)
count_val_train = count.fit_transform(clean_train,y_train)
count_val_test = count.transform(clean_test)

# %%
count_val_train
# Out:
# <30000x1000 sparse matrix of type '<class 'numpy.int64'>'
# 	with 1657115 stored elements in Compressed Sparse Row format>

# %%
data = pd.DataFrame(count_val_train.A,columns=count.get_feature_names())

# %%
count.get_feature_names()
# Out:
# ['ability',
#  'able',
#  'absolutely',
#  'accent',
#  'across',
#  'act',
#  'acted',
#  'acting',
#  'action',
#  'actor',
#  'actress',
#  'actual',
#  'actually',
#  'adaptation',
#  'add',
#  'admit',
#  'adult',
#  'adventure',
#  'age',
#  'ago',
#  'agree',
#  'air',
#  'alien',
#  'alive',
#  'almost',
#  'alone',
#  'along',
#  'already',
#  'also',
#  'although',
#  'always',
#  'amazing',
#  'america',
#  'american',
#  'among',
#  'amount',
#  'amusing',
#  'animal',
#  'animation',
#  'annoying',
#  'another',
#  'answer',
#  'anyone',
#  'anything',
#  'anyway',
#  'apart',
#  'apparently',
#  'appear',
#  'appearance',
#  'appears',
#  'appreciate',
#  'army',
#  'around',
#  'art',
#  'aside',
#  'ask',
#  'aspect',
#  'atmosphere',
#  'attack',
#  'attempt',
#  'attention',
#  'audience',
#  'average',
#  'avoid',
#  'award',
#  'away',
#  'awesome',
#  'awful',
#  'baby',
#  'back',
#  'background',
#  'bad',
#  'badly',
#  'band',
#  'based',
#  'basic',
#  'basically',
#  'battle',
#  'beautiful',
#  'beauty',
#  'became',
#  'become',
#  'becomes',
#  'bed',
#  'begin',
#  'beginning',
#  'behind',
#  'belief',
#  'believable',
#  'believe',
#  'ben',
#  'best',
#  'better',
#  'beyond',
#  'big',
#  'biggest',
#  'bill',
#  'bit',
#  'bizarre',
#  'black',
#  'blood',
#  'blue',
#  'body',
#  'book',
#  'bored',
#  'boring',
#  'bother',
#  'bought',
#  'box',
#  'boy',
#  'br',
#  'brain',
#  'break',
#  'brilliant',
#  'bring',
#  'brings',
#  'british',
#  'brother',
#  'brought',
#  'budget',
#  'building',
#  'bunch',
#  'business',
#  'buy',
#  'call',
#  'called',
#  'came',
#  'camera',
#  'camp',
#  'car',
#  'care',
#  'career',
#  'carry',
#  'cartoon',
#  'case',
#  'cast',
#  'casting',
#  'cat',
#  'catch',
#  'caught',
#  'century',
#  'certain',
#  'certainly',
#  'chance',
#  'change',
#  'changed',
#  'channel',
#  'character',
#  'chase',
#  'cheap',
#  'check',
#  'cheesy',
#  'child',
#  'choice',
#  'cinema',
#  'cinematography',
#  'city',
#  'class',
#  'classic',
#  'clear',
#  'clearly',
#  'clever',
#  'cliche',
#  'close',
#  'cold',
#  'college',
#  'color',
#  'come',
#  'comedy',
#  'comic',
#  'coming',
#  'comment',
#  'common',
#  'company',
#  'compared',
#  'complete',
#  'completely',
#  'computer',
#  'concept',
#  'consider',
#  'considering',
#  'control',
#  'convincing',
#  'cool',
#  'cop',
#  'copy',
#  'costume',
#  'could',
#  'country',
#  'couple',
#  'course',
#  'cover',
#  'crap',
#  'crazy',
#  'create',
#  'created',
#  'creature',
#  'credit',
#  'creepy',
#  'crew',
#  'crime',
#  'critic',
#  'cry',
#  'culture',
#  'cut',
#  'cute',
#  'dance',
#  'dancing',
#  'dark',
#  'daughter',
#  'david',
#  'day',
#  'de',
#  'dead',
#  'deal',
#  'death',
#  'decent',
#  'decide',
#  'decided',
#  'decides',
#  'deep',
#  'definitely',
#  'depth',
#  'deserves',
#  'despite',
#  'detail',
#  'development',
#  'dialog',
#  'dialogue',
#  'die',
#  'died',
#  'different',
#  'difficult',
#  'directed',
#  'directing',
#  'direction',
#  'director',
#  'disappointed',
#  'disney',
#  'doctor',
#  'documentary',
#  'dog',
#  'done',
#  'door',
#  'doubt',
#  'drama',
#  'dramatic',
#  'dream',
#  'drive',
#  'drug',
#  'due',
#  'dull',
#  'dumb',
#  'dvd',
#  'earlier',
#  'early',
#  'earth',
#  'easily',
#  'easy',
#  'editing',
#  'effect',
#  'effective',
#  'effort',
#  'either',
#  'element',
#  'else',
#  'emotion',
#  'emotional',
#  'end',
#  'ended',
#  'ending',
#  'english',
#  'enjoy',
#  'enjoyable',
#  'enjoyed',
#  'enough',
#  'entertaining',
#  'entertainment',
#  'entire',
#  'entirely',
#  'episode',
#  'era',
#  'escape',
#  'especially',
#  'etc',
#  'even',
#  'event',
#  'eventually',
#  'ever',
#  'every',
#  'everyone',
#  'everything',
#  'evil',
#  'exactly',
#  'example',
#  'excellent',
#  'except',
#  'exciting',
#  'expect',
#  'expected',
#  'expecting',
#  'experience',
#  'extra',
#  'extremely',
#  'eye',
#  'face',
#  'fact',
#  'fails',
#  'fairly',
#  'fake',
#  'fall',
#  'familiar',
#  'family',
#  'famous',
#  'fan',
#  'fantastic',
#  'fantasy',
#  'far',
#  'fast',
#  'father',
#  'favorite',
#  'fear',
#  'feature',
#  'feel',
#  'feeling',
#  'felt',
#  'female',
#  'fight',
#  'fighting',
#  'figure',
#  'filled',
#  'film',
#  'filmed',
#  'filmmaker',
#  'final',
#  'finally',
#  'find',
#  'fine',
#  'fire',
#  'first',
#  'fit',
#  'five',
#  'flat',
#  'flaw',
#  'flick',
#  'focus',
#  'follow',
#  'following',
#  'follows',
#  'footage',
#  'force',
#  'forced',
#  'forget',
#  'form',
#  'former',
#  'forward',
#  'found',
#  'four',
#  'free',
#  'french',
#  'friend',
#  'front',
#  'full',
#  'fun',
#  'funny',
#  'future',
#  'game',
#  'gang',
#  'gave',
#  'gay',
#  'general',
#  'genius',
#  'genre',
#  'george',
#  'german',
#  'get',
#  'getting',
#  'ghost',
#  'girl',
#  'girlfriend',
#  'give',
#  'given',
#  'giving',
#  'go',
#  'god',
#  'going',
#  'gone',
#  'good',
#  'gore',
#  'got',
#  'great',
#  'greatest',
#  'group',
#  'guess',
#  'gun',
#  'guy',
#  'hair',
#  'half',
#  'hand',
#  'happen',
#  'happened',
#  'happens',
#  'happy',
#  'hard',
#  'hardly',
#  'hate',
#  'head',
#  'hear',
#  'heard',
#  'heart',
#  'hell',
#  'help',
#  'hero',
#  'high',
#  'highly',
#  'hilarious',
#  'history',
#  'hit',
#  'hold',
#  'hole',
#  'hollywood',
#  'home',
#  'honestly',
#  'hope',
#  'horrible',
#  'horror',
#  'hot',
#  'hour',
#  'house',
#  'however',
#  'huge',
#  'human',
#  'humor',
#  'husband',
#  'idea',
#  'image',
#  'imagine',
#  'imdb',
#  'important',
#  'impossible',
#  'including',
#  'incredible',
#  'incredibly',
#  'indeed',
#  'indian',
#  'inside',
#  'instead',
#  'intelligent',
#  'interest',
#  'interested',
#  'interesting',
#  'involved',
#  'island',
#  'issue',
#  'italian',
#  'jack',
#  'james',
#  'japanese',
#  'job',
#  'joe',
#  'john',
#  'joke',
#  'keep',
#  'kept',
#  'kid',
#  'kill',
#  'killed',
#  'killer',
#  'killing',
#  'kind',
#  'king',
#  'knew',
#  'know',
#  'known',
#  'la',
#  'lack',
#  'lady',
#  'lame',
#  'land',
#  'language',
#  'large',
#  'last',
#  'late',
#  'later',
#  'laugh',
#  'laughing',
#  'law',
#  'le',
#  'lead',
#  'leading',
#  'leaf',
#  'learn',
#  'least',
#  'leave',
#  'lee',
#  'left',
#  'let',
#  'level',
#  'lie',
#  'life',
#  'light',
#  'like',
#  'liked',
#  'line',
#  'list',
#  'little',
#  'live',
#  'living',
#  'local',
#  'location',
#  'long',
#  'look',
#  'looked',
#  'looking',
#  'lost',
#  'lot',
#  'love',
#  'loved',
#  'lover',
#  'low',
#  'mad',
#  'made',
#  'main',
#  'major',
#  'make',
#  'maker',
#  'making',
#  'male',
#  'man',
#  'manages',
#  'many',
#  'mark',
#  'married',
#  'master',
#  'masterpiece',
#  'match',
#  'material',
#  'matter',
#  'may',
#  'maybe',
#  'mean',
#  'meaning',
#  'meant',
#  'meet',
#  'member',
#  'memorable',
#  'memory',
#  'men',
#  'mention',
#  'mentioned',
#  'mess',
#  'message',
#  'michael',
#  'middle',
#  'might',
#  'million',
#  'mind',
#  'minute',
#  'miss',
#  'missed',
#  'missing',
#  'mistake',
#  'modern',
#  'moment',
#  'money',
#  'monster',
#  'mostly',
#  'mother',
#  'move',
#  'movie',
#  'moving',
#  'much',
#  'murder',
#  'music',
#  'musical',
#  'must',
#  'mystery',
#  'name',
#  'named',
#  'nature',
#  'near',
#  'nearly',
#  'need',
#  'needed',
#  'neither',
#  'never',
#  'new',
#  'next',
#  'nice',
#  'night',
#  'no',
#  'none',
#  'nor',
#  'not',
#  'note',
#  'nothing',
#  'novel',
#  'nudity',
#  'number',
#  'obvious',
#  'obviously',
#  'odd',
#  'offer',
#  'office',
#  'often',
#  'oh',
#  'ok',
#  'okay',
#  'old',
#  'older',
#  'one',
#  'open',
#  'opening',
#  'opinion',
#  'order',
#  'original',
#  'oscar',
#  'others',
#  'otherwise',
#  'outside',
#  'overall',
#  'pace',
#  'parent',
#  'park',
#  'part',
#  'particular',
#  'particularly',
#  'party',
#  'past',
#  'paul',
#  'pay',
#  'people',
#  'perfect',
#  'perfectly',
#  'performance',
#  'perhaps',
#  'period',
#  'person',
#  'personal',
#  'peter',
#  'pick',
#  'picture',
#  'piece',
#  'place',
#  'plain',
#  'plan',
#  'play',
#  'played',
#  'player',
#  'playing',
#  'please',
#  'plenty',
#  'plot',
#  'plus',
#  'point',
#  'pointless',
#  'police',
#  'political',
#  'poor',
#  'poorly',
#  'popular',
#  'portrayal',
#  'portrayed',
#  'positive',
#  'possible',
#  'possibly',
#  'potential',
#  'power',
#  'powerful',
#  'predictable',
#  'premise',
#  'present',
#  'pretty',
#  'previous',
#  'prison',
#  'probably',
#  'problem',
#  'produced',
#  'producer',
#  'production',
#  'project',
#  'public',
#  'pull',
#  'pure',
#  'purpose',
#  'put',
#  'quality',
#  'question',
#  'quickly',
#  'quite',
#  'rate',
#  'rather',
#  'rating',
#  'read',
#  'reading',
#  'real',
#  'realistic',
#  'reality',
#  'realize',
#  'really',
#  'reason',
#  'recent',
#  'recently',
#  'recommend',
#  'recommended',
#  'red',
#  'relationship',
#  'release',
#  'released',
#  'remake',
#  'remember',
#  'rent',
#  'respect',
#  'rest',
#  'result',
#  'return',
#  'review',
#  'reviewer',
#  'rich',
#  'richard',
#  'ride',
#  'ridiculous',
#  'right',
#  'ring',
#  'road',
#  'robert',
#  'rock',
#  'role',
#  'romance',
#  'romantic',
#  'room',
#  'run',
#  'running',
#  'sad',
#  'sadly',
#  'said',
#  'save',
#  'saw',
#  'say',
#  'saying',
#  'scary',
#  'scene',
#  'school',
#  'science',
#  'scientist',
#  'score',
#  'scott',
#  'screen',
#  'screenplay',
#  'script',
#  'season',
#  'second',
#  'secret',
#  'see',
#  'seeing',
#  'seem',
#  'seemed',
#  'seems',
#  'seen',
#  'sense',
#  'sequel',
#  'sequence',
#  'series',
#  'serious',
#  'seriously',
#  'set',
#  'setting',
#  'several',
#  'sex',
#  'sexual',
#  'shame',
#  'ship',
#  'shoot',
#  'shooting',
#  'short',
#  'shot',
#  'show',
#  'showed',
#  'showing',
#  'shown',
#  'side',
#  'silly',
#  'similar',
#  'simple',
#  'simply',
#  'since',
#  'singing',
#  'single',
#  'sister',
#  'sit',
#  'situation',
#  'slightly',
#  'slow',
#  'small',
#  'social',
#  'society',
#  'soldier',
#  'somehow',
#  'someone',
#  'something',
#  'sometimes',
#  'somewhat',
#  'son',
#  'song',
#  'soon',
#  'sorry',
#  'sort',
#  'soul',
#  'sound',
#  'soundtrack',
#  'space',
#  'speak',
#  'special',
#  'spend',
#  'spent',
#  'spirit',
#  'spoiler',
#  'stage',
#  'stand',
#  'standard',
#  'star',
#  'start',
#  'started',
#  'state',
#  'stay',
#  'steal',
#  'stick',
#  'still',
#  'stop',
#  'store',
#  'story',
#  'storyline',
#  'straight',
#  'strange',
#  'street',
#  'strong',
#  'student',
#  'studio',
#  'stuff',
#  'stupid',
#  'style',
#  'subject',
#  'success',
#  'successful',
#  'suddenly',
#  'superb',
#  'supporting',
#  'supposed',
#  'sure',
#  'surprise',
#  'surprised',
#  'suspense',
#  'sweet',
#  'take',
#  'taken',
#  'taking',
#  'tale',
#  'talent',
#  'talented',
#  'talk',
#  'talking',
#  'taste',
#  'team',
#  'teen',
#  'teenager',
#  'television',
#  'tell',
#  'telling',
#  'ten',
#  'tension',
#  'term',
#  'terrible',
#  'thanks',
#  'theater',
#  'theme',
#  'thing',
#  'think',
#  'thinking',
#  'third',
#  'though',
#  'thought',
#  'three',
#  'thriller',
#  'throughout',
#  'throw',
#  'time',
#  'title',
#  'today',
#  'together',
#  'told',
#  'tom',
#  'took',
#  'top',
#  'total',
#  'totally',
#  'touch',
#  'towards',
#  'town',
#  'track',
#  'train',
#  'tried',
#  'trip',
#  'trouble',
#  'true',
#  'truly',
#  'truth',
#  'try',
#  'trying',
#  'turn',
#  'turned',
#  'tv',
#  'twist',
#  'two',
#  'type',
#  'typical',
#  'ultimately',
#  'understand',
#  'unfortunately',
#  'unique',
#  'unless',
#  'unlike',
#  'upon',
#  'us',
#  'use',
#  'used',
#  'using',
#  'usual',
#  'usually',
#  'value',
#  'vampire',
#  'van',
#  'various',
#  'version',
#  'victim',
#  'video',
#  'view',
#  'viewer',
#  'viewing',
#  'villain',
#  'violence',
#  'violent',
#  'visual',
#  'voice',
#  'wait',
#  'waiting',
#  'walk',
#  'want',
#  'wanted',
#  'war',
#  'waste',
#  'wasted',
#  'watch',
#  'watched',
#  'watching',
#  'water',
#  'way',
#  'weak',
#  'week',
#  'weird',
#  'well',
#  'went',
#  'western',
#  'whatever',
#  'whether',
#  'white',
#  'whole',
#  'whose',
#  'wife',
#  'william',
#  'win',
#  'wish',
#  'within',
#  'without',
#  'woman',
#  'wonder',
#  'wonderful',
#  'wood',
#  'word',
#  'work',
#  'worked',
#  'working',
#  'world',
#  'worse',
#  'worst',
#  'worth',
#  'would',
#  'write',
#  'writer',
#  'writing',
#  'written',
#  'wrong',
#  'wrote',
#  'yeah',
#  'year',
#  'yes',
#  'yet',
#  'york',
#  'young',
#  'younger',
#  'zombie']

# %% [markdown]
# #  Model Building

# %%
count_mnb = MultinomialNB()
count_mnb.fit(count_val_train.A,y_train)
# Out:
# MultinomialNB()

# %%
predicted_y = count_mnb.predict(count_val_test.A)

# %%
count_acc = accuracy_score(y_test,predicted_y)*100
count_acc
# Out:
# 83.31

# %% [markdown]
# # Tfidf Vectorizer

# %%
tfidf = TfidfVectorizer(max_features=1000,max_df=0.95,min_df=1)
tfidf_val_train = tfidf.fit_transform(clean_train,y_train)
tfidf_val_test = tfidf.transform(clean_test)

# %%
pd.DataFrame(tfidf_val_train.A,columns=tfidf.get_feature_names())
# Out:
#        ability      able  absolutely  accent  across       act  acted  \
# 0          0.0  0.000000         0.0     0.0     0.0  0.000000    0.0
# 1          0.0  0.000000         0.0     0.0     0.0  0.000000    0.0
# 2          0.0  0.000000         0.0     0.0     0.0  0.000000    0.0
# 3          0.0  0.117108         0.0     0.0     0.0  0.000000    0.0
# 4          0.0  0.000000         0.0     0.0     0.0  0.075478    0.0
# ...        ...       ...         ...     ...     ...       ...    ...
# 29995      0.0  0.066141         0.0     0.0     0.0  0.000000    0.0
# 29996      0.0  0.000000         0.0     0.0     0.0  0.000000    0.0
# 29997      0.0  0.000000         0.0     0.0     0.0  0.000000    0.0
# 29998      0.0  0.071574         0.0     0.0     0.0  0.000000    0.0
# 29999      0.0  0.000000         0.0     0.0     0.0  0.000000    0.0
#
#          acting  action     actor  ...  wrong  wrote  yeah      year  yes  \
# 0      0.000000     0.0  0.000000  ...    0.0    0.0   0.0  0.000000  0.0
# 1      0.000000     0.0  0.000000  ...    0.0    0.0   0.0  0.000000  0.0
# 2      0.000000     0.0  0.000000  ...    0.0    0.0   0.0  0.000000  0.0
# 3      0.000000     0.0  0.000000  ...    0.0    0.0   0.0  0.000000  0.0
# 4      0.000000     0.0  0.000000  ...    0.0    0.0   0.0  0.000000  0.0
# ...         ...     ...       ...  ...    ...    ...   ...       ...  ...
# 29995  0.000000     0.0  0.000000  ...    0.0    0.0   0.0  0.000000  0.0
# 29996  0.000000     0.0  0.000000  ...    0.0    0.0   0.0  0.194612  0.0
# 29997  0.000000     0.0  0.000000  ...    0.0    0.0   0.0  0.000000  0.0
# 29998  0.089954     0.0  0.000000  ...    0.0    0.0   0.0  0.047505  0.0
# 29999  0.085073     0.0  0.348882  ...    0.0    0.0   0.0  0.000000  0.0
#
#        yet      york     young   younger  zombie
# 0      0.0  0.000000  0.000000  0.000000     0.0
# 1      0.0  0.000000  0.000000  0.000000     0.0
# 2      0.0  0.000000  0.000000  0.000000     0.0
# 3      0.0  0.000000  0.000000  0.000000     0.0
# 4      0.0  0.000000  0.000000  0.000000     0.0
# ...    ...       ...       ...       ...     ...
# 29995  0.0  0.078977  0.052978  0.081266     0.0
# 29996  0.0  0.000000  0.000000  0.000000     0.0
# 29997  0.0  0.000000  0.000000  0.000000     0.0
# 29998  0.0  0.000000  0.000000  0.000000     0.0
# 29999  0.0  0.000000  0.000000  0.000000     0.0
#
# [30000 rows x 1000 columns]

# %%
tfidf_mnb = MultinomialNB()
tfidf_mnb.fit(tfidf_val_train.A,y_train)
predicted_y = tfidf_mnb.predict(tfidf_val_test.A)
tfidf_acc = accuracy_score(y_test,predicted_y)*100
tfidf_acc
# Out:
# 83.82

# %%
count_acc
# Out:
# 83.31
